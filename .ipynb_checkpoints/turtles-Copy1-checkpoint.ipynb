# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
import numpy as np
import random

init_notebook_mode(connected=True)
it_count = 600
N = 5
maxX = 300
maxY = 500

def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

turtles = []
frames = []
for it in range(it_count):
    m_x = []
    m_y = []
    for i in range(N):
        if it == 0:
            trt = dict(x = [random.randint(0, maxX)], y = [random.randint(0, maxY)])
            turtles.append(trt)
        else:
            next_trt = 0 if i == (N - 1)  else (i + 1)
            next_trt = turtles[next_trt]
            
            dx = next_trt['x'][-1] - turtles[i]['x'][-1]
            dy = next_trt['y'][-1] - turtles[i]['y'][-1]
            d = normalized(np.array([dx, dy]))
            turtles[i]['x'].append(turtles[i]['x'][-1] + d[0][0])
            turtles[i]['y'].append(turtles[i]['y'][-1] + d[0][1])
        m_x.append(turtles[i]['x'][-1])
        m_y.append(turtles[i]['y'][-1])
    
    frames.append(dict(data=[dict(x=m_x, 
                        y=m_y, 
                        mode='markers', 
                        marker=dict(color='red', size=10)
                        )
                  ]) ) 
        

#print(turtles)




data=[dict(x=x, y=y, 
           mode='lines', 
           line=dict(width=2, color='blue')
          )
    ]

layout=dict(xaxis=dict(range = [0, maxX * 10], autorange=False, zeroline=False),
            yaxis=dict(range = [0, maxY * 10],autorange=False, zeroline=False),
            title='Trt', hovermode='closest',
            updatemenus= [{'type': 'buttons',
                           'buttons': [{'label': 'Play',
                                        'method': 'animate',
                                        'args': [None]}]}])
'''
frames=[dict(data=[dict(x=[turtles[i]['x'][it]], 
                        y=[turtles[i]['y'][it]], 
                        mode='markers', 
                        marker=dict(color='red', size=10)
                        )
                  ])for i in range(N) for it in range(it_count)]    
  '''        
figure1=dict(data=data, layout=layout, frames=frames)          
iplot(figure1)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="511f328b-45a6-4f61-961e-f94db7aa27fa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '511f328b-45a6-4f61-961e-f94db7aa27fa',
#             [{"x": [0.0, -0.01979389858177738, -0.03877155392306908, -0.0569329660238751, -0.07427813488419543, -0.0908070605040302, -0.10651974288337929, -0.12141618202224269, -0.13549637792062041, -0.14876033057851246, -0.16120803999591882, -0.1728395061728395, -0.1836547291092746, -0.19365370880522392, -0.20283644526068767, -0.21120293847566574, -0.21875318845015818, -0.22548719518416488, -0.23140495867768596, -0.23650647893072135, -0.24079175594327112, -0.24426078971533516, -0.24691358024691357, -0.24875012753800635, -0.2497704315886134, -0.24997449239873482, -0.24936230996837058, -0.24793388429752067, -0.24568921538618507, -0.24262830323436385, -0.23875114784205692, -0.23405774920926437, -0.22854810733598613, -0.2222222222222222, -0.2150800938679726, -0.20712172227323739, -0.